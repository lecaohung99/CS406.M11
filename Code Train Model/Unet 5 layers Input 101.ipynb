# %%
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.27-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Imports
import os
import sys
import random
import numpy as np
from numpy import save
from numpy import load
#
import pandas as pd
import seaborn as sns
from PIL import Image
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator
#
import cv2
import matplotlib.pyplot as plt
from glob import glob
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, 
    BatchNormalization,
    Activation,
    Dense,
    Dropout,
    MaxPooling2D, 
    GlobalMaxPool2D,
    Conv2D,
    Conv2DTranspose,
    UpSampling2D,
    concatenate,
    add,
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

## Seeding
seed=2019
random.seed=seed
np.random.seed=seed
tf.seed=seed

# %%
depths = pd.read_csv('./drive/My Drive/ImageProcessing/depths.csv')
data = pd.read_csv('./drive/My Drive/ImageProcessing/train.csv')
Data = pd.merge(data,depths,on='id',how='left')

# %%
# Converting the image into the desired form
def load_image(img_path, dsize=(101,101)):
  img = cv2.imread(img_path)
  O_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  O_img = cv2.resize(O_img, dsize)
  
  #Original
  O_img_tensor = img_to_array(O_img)

  #Rotate +90
  #R_img = cv2.rotate(O_img, cv2.ROTATE_90_CLOCKWISE)
  #R_img_tensor = img_to_array(R_img)
  
  #flipud
  Flip_ud = cv2.flip(O_img, 0)
  Flip_ud_tensor = img_to_array(Flip_ud)
  
  #fliplr
  Flip_lr = cv2.flip(O_img, 1)
  Flip_lr_tensor = img_to_array(Flip_lr)

  return O_img_tensor, Flip_lr_tensor, Flip_ud_tensor

# %%
def get_data(filetrains, filevalids):

  path='./drive/My Drive/ImageProcessing/dataset/train'
  
  x_train=[]
  y_train=[]
  
  x_valid=[]
  y_valid=[]


  #print(os.walk(path)
  for files in filetrains:
    img,R_img,N_img = load_image(path+'/images/'+ files + '.png')
    mask,R_mask,N_mask = load_image(path+'/masks/'+ files + '.png')    
    
    img=img/255.0
    mask=mask/255.0
    
    if files not in filevalids:
      R_img=R_img/255.0
      R_mask=R_mask/255.0
      #N_img=N_img/255.0
      #N_mask=N_mask/255.0

      x_train.append(img)
      y_train.append(mask)

      x_train.append(R_img)
      y_train.append(R_mask)

      #x_train.append(N_img)
      #y_train.append(N_mask)

    else:
      x_valid.append(img)
      y_valid.append(mask)
  return np.asarray(x_train), np.asarray(y_train), np.asarray(x_valid), np.asarray(y_valid)

# %%
X_test=pd.read_csv('./drive/My Drive/ImageProcessing/test_800.csv')

# %%
X_test=pd.read_csv('./drive/My Drive/ImageProcessing/test_400.csv')

# %%
X_test
# Out:
#              id                                           rle_mask    z
# 0    b6bbd06618  6490 5 6592 8 6694 11 6795 15 6897 18 6999 21 ...  536
# 1    b5b767492b  1 9089 9091 96 9192 90 9293 85 9394 79 9495 73...  676
# 2    3d781526c2  3738 1 3839 2 3940 3 4041 4 4142 6 4243 7 4344...  596
# 3    6ef46555e2  1568 22 1668 33 1768 43 1869 50 1969 52 2069 5...  385
# 4    0243477802                                                NaN  261
# ..          ...                                                ...  ...
# 395  155bcd4b4d  4842 7 4936 14 5031 20 5126 26 5220 33 5314 40...  712
# 396  340c808130  3839 1 3940 1 4041 2 4142 2 4243 3 4344 4 4445...  660
# 397  d35af24206  1 70 102 69 203 68 304 66 405 61 506 57 607 52...  782
# 398  fad11bf2fa  1617 1 1718 2 1819 3 1920 5 2021 6 2122 7 2223...  371
# 399  5e350fa662  5151 1 5250 3 5350 4 5450 5 5550 6 5649 8 5749...  441
#
# [400 rows x 3 columns]

# %%
X_train=pd.read_csv('/content/drive/MyDrive/ImageProcessing/train_3600.csv')

# %%
X_train
# Out:
#               id                                           rle_mask    z
# 0     eeecc7ab39  1 5150 5152 98 5253 97 5354 96 5455 95 5556 94...  499
# 1     868e7a70ae                                                NaN  286
# 2     d468d401ab  6388 10 6476 37 6569 57 6668 71 6768 83 6869 9...  408
# 3     70c8e14243  3229 4 3325 9 3420 15 3516 20 3611 26 3707 31 ...  544
# 4     25db231ea0  1111 1 1212 1 1312 2 1412 3 1513 3 1613 4 1713...  581
# ...          ...                                                ...  ...
# 3595  638d8572e9  91 11 188 15 285 19 381 24 477 29 573 34 669 3...  336
# 3596  ac7df612ff  1 34 102 34 203 34 304 34 405 34 506 34 607 33...  614
# 3597  46386ca4a3  1 18 102 18 203 18 304 18 405 18 506 18 607 18...  695
# 3598  619edf8941                                                NaN  625
# 3599  d800abe6a4  1 1344 1346 100 1448 99 1550 98 1651 98 1753 9...  709
#
# [3600 rows x 3 columns]

# %%
X_train['z'].plot(kind='hist')

# %%
X=X_train.sort_values('z')

# %%
X=X.drop('z',axis=1)

# %%
X=X.drop('rle_mask', axis=1)

# %%
X['fold'] = (list(range(5)) * X.shape[0])[:X.shape[0]]

# %%
df0 = X.loc[X['fold']==0]
df1 = X.loc[X['fold']==1]
df2 = X.loc[X['fold']==2]
df3 = X.loc[X['fold']==3]
df4 = X.loc[X['fold']==4]

# %%
f0 = pd.merge(X_train,df0,on='id',how='left')
f1 = pd.merge(X_train,df1,on='id',how='left')
f2 = pd.merge(X_train,df2,on='id',how='left')
f3 = pd.merge(X_train,df3,on='id',how='left')
f4 = pd.merge(X_train,df4,on='id',how='left')

# %%
fold=[1,2,3,4,5]
fold[0]=f0.loc[f0['fold']==0]
fold[1]=f1.loc[f1['fold']==1]
fold[2]=f2.loc[f2['fold']==2]
fold[3]=f3.loc[f3['fold']==3]
fold[4]=f4.loc[f4['fold']==4]

# %%
X_train['id'].values
# Out:
# array(['eeecc7ab39', '868e7a70ae', 'd468d401ab', ..., '46386ca4a3',
#        '619edf8941', 'd800abe6a4'], dtype=object)

# %%
fold[0]['z'].plot(kind='hist')

# %%
fold[1]['z'].plot(kind='hist')

# %%
fold[2]['z'].plot(kind='hist')

# %%
fold[3]['z'].plot(kind='hist')

# %%
fold[4]['z'].plot(kind='hist')

# %%
# I tried to make it as simple as possible, I think you can understand the architecture just by looking at the code below
def UNet(input_img):

    c1 = Conv2D(16, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(input_img)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    
    c1 = Conv2D(16, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c1)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.1)(p1)
#-----------------------------------------------------------------------------------------------------------------    
    
    c2 = Conv2D(32, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    
    c2 = Conv2D(32, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c2)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.1)(p2) 
#-----------------------------------------------------------------------------------------------------------------    
    
    c3 = Conv2D(64, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    
    c3 = Conv2D(64, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c3)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.1)(p3) 
    
#-----------------------------------------------------------------------------------------------------------------    
    
    c4 = Conv2D(128, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = Activation('relu')(c4)
    
    c4 = Conv2D(128, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c4)
    c4 = BatchNormalization()(c4)
    c4 = Activation('relu')(c4)
    
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.1)(p4) 
    
#-----------------------------------------------------------------------------------------------------------------    
    
    c5 = Conv2D(256, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(p4)
    c5 = BatchNormalization()(c5)
    c5 = Activation('relu')(c5)
    
    c5 = Conv2D(256, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c5)
    c5 = BatchNormalization()(c5)
    c5 = Activation('relu')(c5)
    
#------UMSAMPLE STARTS---------------------------------------------------------------------------------------------

    u6 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    
    c6 = Conv2D(128, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(u6)
    c6 = BatchNormalization()(c6)
    c6 = Activation('relu')(c6)
    
    c6 = Conv2D(128, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c6)
    c6 = BatchNormalization()(c6)
    c6 = Activation('relu')(c6)
    
#---------------------------------------------------------------------------------------------------

    u7 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'valid')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    
    c7 = Conv2D(64, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = Activation('relu')(c7)
    
    c7 = Conv2D(64, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c7)
    c7 = BatchNormalization()(c7)
    c7 = Activation('relu')(c7)
    
#---------------------------------------------------------------------------------------------------

    u8 = Conv2DTranspose(32, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    
    c8 = Conv2D(32, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = Activation('relu')(c8)

    c8 = Conv2D(32, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c8)
    c8 = BatchNormalization()(c8)
    c8 = Activation('relu')(c8)
    
#---------------------------------------------------------------------------------------------------

    u9 = Conv2DTranspose(16, (3, 3), strides = (2, 2), padding = 'valid')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    
    c9 = Conv2D(16, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = Activation('relu')(c9)
    
    c9 = Conv2D(16, kernel_size = (3,3), kernel_initializer = 'he_normal', padding = 'same')(c9)
    c9 = BatchNormalization()(c9)
    c9 = Activation('relu')(c9)
    
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

 
    
    model = Model(input_img, outputs)
    return model

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0      
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))
    return np.mean(metric)

def iou_metric(label, pred):
    return tf.compat.v1.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

# %%
input_img=Input((101, 101, 1), name='img')
model=UNet(input_img)
model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=[iou_metric])
#model.summary()

# %%
from tensorflow.keras.utils import plot_model
#plot_model(model, to_file='2D_5layer_U-Net_Model.png')

# %%
#Using EarlyStopping to stop the training if the algorithm is not converging, 
#ReduceLROnPlateau to change the learning rate in runtime if the algorithm is not converging,
#ModelCheckpoint to save the model time to time whenever there is a imporvement
callbacks = [
    ReduceLROnPlateau(patience=5, verbose=1, monitor='val_iou_metric', min_lr=0.0001, mode ='max', factor=0.5),
    ModelCheckpoint('./drive/My Drive/ImageProcessing/unet_input101_5GD.h5', monitor='val_iou_metric', mode = 'max', verbose=1, save_best_only=True),
    EarlyStopping(monitor='val_iou_metric', mode='max', verbose=1, patience=30)
]

# %%
#model.load_weights('./drive/My Drive/ImageProcessing/unet_input128_5GD_50ep.h5')

# %%
history=[1,2,3,4,5]
ep=100

for i in range(4, 5):
  print("###### TRAIN", i, " ######")
  x_train, y_train, x_valid, y_valid = get_data(X_train['id'].values, fold[i]['id'].values)
  print('len(x_train):',len(x_train),'len(y_train):',len(y_train),'len(x_valid):',len(x_valid), 'len(y_valid):',len(y_valid))
  # train the network
  history[i]=model.fit(x_train, y_train, batch_size=32, epochs=ep, callbacks=callbacks, validation_data=(x_valid,y_valid))
  model.save(r'./drive/My Drive/ImageProcessing/unet_input101_5GD_final.h5')
  #np.save('./drive/My Drive/ImageProcessing/my_history_unet_input101_5_GD.npy',history[i].history)
  print(K.eval(model.optimizer.lr))
# Out:
# ###### TRAIN 4  ######
# len(x_train): 5760 len(y_train): 5760 len(x_valid): 720 len(y_valid): 720
# Epoch 1/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3535 - iou_metric: 0.3856
# Epoch 00001: val_iou_metric improved from -inf to 0.16264, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 34s 170ms/step - loss: 0.3535 - iou_metric: 0.3856 - val_loss: 3.7573 - val_iou_metric: 0.1626 - lr: 0.0010
# Epoch 2/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2695 - iou_metric: 0.5354
# Epoch 00002: val_iou_metric improved from 0.16264 to 0.35910, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.2695 - iou_metric: 0.5354 - val_loss: 1.0102 - val_iou_metric: 0.3591 - lr: 0.0010
# Epoch 3/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2309 - iou_metric: 0.5757
# Epoch 00003: val_iou_metric improved from 0.35910 to 0.39497, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.2309 - iou_metric: 0.5757 - val_loss: 0.4629 - val_iou_metric: 0.3950 - lr: 0.0010
# Epoch 4/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2119 - iou_metric: 0.5966
# Epoch 00004: val_iou_metric improved from 0.39497 to 0.61005, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 30s 164ms/step - loss: 0.2119 - iou_metric: 0.5966 - val_loss: 0.2910 - val_iou_metric: 0.6101 - lr: 0.0010
# Epoch 5/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1919 - iou_metric: 0.6159
# Epoch 00005: val_iou_metric did not improve from 0.61005
# 180/180 [==============================] - 28s 158ms/step - loss: 0.1919 - iou_metric: 0.6159 - val_loss: 0.2973 - val_iou_metric: 0.5424 - lr: 0.0010
# Epoch 6/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1848 - iou_metric: 0.6378
# Epoch 00006: val_iou_metric did not improve from 0.61005
# 180/180 [==============================] - 28s 158ms/step - loss: 0.1848 - iou_metric: 0.6378 - val_loss: 0.2328 - val_iou_metric: 0.5855 - lr: 0.0010
# Epoch 7/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1742 - iou_metric: 0.6512
# Epoch 00007: val_iou_metric improved from 0.61005 to 0.63750, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 30s 164ms/step - loss: 0.1742 - iou_metric: 0.6512 - val_loss: 0.2170 - val_iou_metric: 0.6375 - lr: 0.0010
# Epoch 8/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1637 - iou_metric: 0.6643
# Epoch 00008: val_iou_metric improved from 0.63750 to 0.68370, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.1637 - iou_metric: 0.6643 - val_loss: 0.1784 - val_iou_metric: 0.6837 - lr: 0.0010
# Epoch 9/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1519 - iou_metric: 0.6758
# Epoch 00009: val_iou_metric did not improve from 0.68370
# 180/180 [==============================] - 28s 158ms/step - loss: 0.1519 - iou_metric: 0.6758 - val_loss: 0.2039 - val_iou_metric: 0.6083 - lr: 0.0010
# Epoch 10/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1508 - iou_metric: 0.6768
# Epoch 00010: val_iou_metric did not improve from 0.68370
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1508 - iou_metric: 0.6768 - val_loss: 0.4142 - val_iou_metric: 0.5436 - lr: 0.0010
# Epoch 11/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1452 - iou_metric: 0.6914
# Epoch 00011: val_iou_metric did not improve from 0.68370
# 180/180 [==============================] - 29s 158ms/step - loss: 0.1452 - iou_metric: 0.6914 - val_loss: 0.2247 - val_iou_metric: 0.6736 - lr: 0.0010
# Epoch 12/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1426 - iou_metric: 0.6928
# Epoch 00012: val_iou_metric improved from 0.68370 to 0.69416, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 30s 164ms/step - loss: 0.1426 - iou_metric: 0.6928 - val_loss: 0.1882 - val_iou_metric: 0.6942 - lr: 0.0010
# Epoch 13/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1396 - iou_metric: 0.6892
# Epoch 00013: val_iou_metric did not improve from 0.69416
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1396 - iou_metric: 0.6892 - val_loss: 0.2160 - val_iou_metric: 0.6732 - lr: 0.0010
# Epoch 14/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1278 - iou_metric: 0.7087
# Epoch 00014: val_iou_metric did not improve from 0.69416
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1278 - iou_metric: 0.7087 - val_loss: 0.1770 - val_iou_metric: 0.6893 - lr: 0.0010
# Epoch 15/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1210 - iou_metric: 0.7082
# Epoch 00015: val_iou_metric improved from 0.69416 to 0.69674, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.1210 - iou_metric: 0.7082 - val_loss: 0.1894 - val_iou_metric: 0.6967 - lr: 0.0010
# Epoch 16/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1138 - iou_metric: 0.7215
# Epoch 00016: val_iou_metric did not improve from 0.69674
# 180/180 [==============================] - 28s 158ms/step - loss: 0.1138 - iou_metric: 0.7215 - val_loss: 0.1647 - val_iou_metric: 0.6939 - lr: 0.0010
# Epoch 17/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1193 - iou_metric: 0.7178
# Epoch 00017: val_iou_metric did not improve from 0.69674
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1193 - iou_metric: 0.7178 - val_loss: 0.2649 - val_iou_metric: 0.6257 - lr: 0.0010
# Epoch 18/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1076 - iou_metric: 0.7197
# Epoch 00018: val_iou_metric did not improve from 0.69674
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1076 - iou_metric: 0.7197 - val_loss: 0.1901 - val_iou_metric: 0.6939 - lr: 0.0010
# Epoch 19/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1018 - iou_metric: 0.7308
# Epoch 00019: val_iou_metric did not improve from 0.69674
# 180/180 [==============================] - 29s 159ms/step - loss: 0.1018 - iou_metric: 0.7308 - val_loss: 0.1992 - val_iou_metric: 0.6697 - lr: 0.0010
# Epoch 20/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1009 - iou_metric: 0.7287
# Epoch 00020: val_iou_metric improved from 0.69674 to 0.71916, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.1009 - iou_metric: 0.7287 - val_loss: 0.1964 - val_iou_metric: 0.7192 - lr: 0.0010
# Epoch 21/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0981 - iou_metric: 0.7295
# Epoch 00021: val_iou_metric did not improve from 0.71916
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0981 - iou_metric: 0.7295 - val_loss: 0.1944 - val_iou_metric: 0.6700 - lr: 0.0010
# Epoch 22/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0917 - iou_metric: 0.7423
# Epoch 00022: val_iou_metric did not improve from 0.71916
# 180/180 [==============================] - 29s 160ms/step - loss: 0.0917 - iou_metric: 0.7423 - val_loss: 0.2370 - val_iou_metric: 0.6734 - lr: 0.0010
# Epoch 23/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0801 - iou_metric: 0.7493
# Epoch 00023: val_iou_metric did not improve from 0.71916
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0801 - iou_metric: 0.7493 - val_loss: 0.1984 - val_iou_metric: 0.6916 - lr: 0.0010
# Epoch 24/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0769 - iou_metric: 0.7558
# Epoch 00024: val_iou_metric did not improve from 0.71916
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0769 - iou_metric: 0.7558 - val_loss: 0.2017 - val_iou_metric: 0.7007 - lr: 0.0010
# Epoch 25/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0725 - iou_metric: 0.7617
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_iou_metric did not improve from 0.71916
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0725 - iou_metric: 0.7617 - val_loss: 0.2110 - val_iou_metric: 0.6772 - lr: 0.0010
# Epoch 26/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0657 - iou_metric: 0.7719
# Epoch 00026: val_iou_metric improved from 0.71916 to 0.72758, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 30s 164ms/step - loss: 0.0657 - iou_metric: 0.7719 - val_loss: 0.1902 - val_iou_metric: 0.7276 - lr: 5.0000e-04
# Epoch 27/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0596 - iou_metric: 0.7729
# Epoch 00027: val_iou_metric improved from 0.72758 to 0.73560, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 29s 164ms/step - loss: 0.0596 - iou_metric: 0.7729 - val_loss: 0.2096 - val_iou_metric: 0.7356 - lr: 5.0000e-04
# Epoch 28/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0538 - iou_metric: 0.7884
# Epoch 00028: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0538 - iou_metric: 0.7884 - val_loss: 0.2022 - val_iou_metric: 0.7249 - lr: 5.0000e-04
# Epoch 29/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0531 - iou_metric: 0.7894
# Epoch 00029: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0531 - iou_metric: 0.7894 - val_loss: 0.2162 - val_iou_metric: 0.7348 - lr: 5.0000e-04
# Epoch 30/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0503 - iou_metric: 0.7969
# Epoch 00030: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0503 - iou_metric: 0.7969 - val_loss: 0.1992 - val_iou_metric: 0.7158 - lr: 5.0000e-04
# Epoch 31/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0509 - iou_metric: 0.7944
# Epoch 00031: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0509 - iou_metric: 0.7944 - val_loss: 0.2024 - val_iou_metric: 0.7215 - lr: 5.0000e-04
# Epoch 32/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0514 - iou_metric: 0.7927
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00032: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0514 - iou_metric: 0.7927 - val_loss: 0.2071 - val_iou_metric: 0.7325 - lr: 5.0000e-04
# Epoch 33/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0455 - iou_metric: 0.8067
# Epoch 00033: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0455 - iou_metric: 0.8067 - val_loss: 0.2086 - val_iou_metric: 0.7336 - lr: 2.5000e-04
# Epoch 34/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0422 - iou_metric: 0.8143
# Epoch 00034: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0422 - iou_metric: 0.8143 - val_loss: 0.2248 - val_iou_metric: 0.7307 - lr: 2.5000e-04
# Epoch 35/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0411 - iou_metric: 0.8162
# Epoch 00035: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0411 - iou_metric: 0.8162 - val_loss: 0.2249 - val_iou_metric: 0.7274 - lr: 2.5000e-04
# Epoch 36/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0401 - iou_metric: 0.8181
# Epoch 00036: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0401 - iou_metric: 0.8181 - val_loss: 0.2059 - val_iou_metric: 0.7149 - lr: 2.5000e-04
# Epoch 37/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0388 - iou_metric: 0.8182
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00037: val_iou_metric did not improve from 0.73560
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0388 - iou_metric: 0.8182 - val_loss: 0.2256 - val_iou_metric: 0.7344 - lr: 2.5000e-04
# Epoch 38/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0381 - iou_metric: 0.8228
# Epoch 00038: val_iou_metric improved from 0.73560 to 0.73832, saving model to ./drive/My Drive/ImageProcessing/unet_input101_5GD.h5
# 180/180 [==============================] - 30s 164ms/step - loss: 0.0381 - iou_metric: 0.8228 - val_loss: 0.2356 - val_iou_metric: 0.7383 - lr: 1.2500e-04
# Epoch 39/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0361 - iou_metric: 0.8265
# Epoch 00039: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0361 - iou_metric: 0.8265 - val_loss: 0.2346 - val_iou_metric: 0.7368 - lr: 1.2500e-04
# Epoch 40/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0363 - iou_metric: 0.8250
# Epoch 00040: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0363 - iou_metric: 0.8250 - val_loss: 0.2282 - val_iou_metric: 0.7223 - lr: 1.2500e-04
# Epoch 41/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0353 - iou_metric: 0.8259
# Epoch 00041: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0353 - iou_metric: 0.8259 - val_loss: 0.2331 - val_iou_metric: 0.7298 - lr: 1.2500e-04
# Epoch 42/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0344 - iou_metric: 0.8302
# Epoch 00042: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0344 - iou_metric: 0.8302 - val_loss: 0.2394 - val_iou_metric: 0.7246 - lr: 1.2500e-04
# Epoch 43/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0341 - iou_metric: 0.8300
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00043: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0341 - iou_metric: 0.8300 - val_loss: 0.2379 - val_iou_metric: 0.7235 - lr: 1.2500e-04
# Epoch 44/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0332 - iou_metric: 0.8327
# Epoch 00044: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 160ms/step - loss: 0.0332 - iou_metric: 0.8327 - val_loss: 0.2424 - val_iou_metric: 0.7298 - lr: 1.0000e-04
# Epoch 45/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0331 - iou_metric: 0.8278
# Epoch 00045: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0331 - iou_metric: 0.8278 - val_loss: 0.2455 - val_iou_metric: 0.7219 - lr: 1.0000e-04
# Epoch 46/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0332 - iou_metric: 0.8358
# Epoch 00046: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0332 - iou_metric: 0.8358 - val_loss: 0.2397 - val_iou_metric: 0.7336 - lr: 1.0000e-04
# Epoch 47/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0322 - iou_metric: 0.8309
# Epoch 00047: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0322 - iou_metric: 0.8309 - val_loss: 0.2417 - val_iou_metric: 0.7249 - lr: 1.0000e-04
# Epoch 48/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0320 - iou_metric: 0.8364
# Epoch 00048: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0320 - iou_metric: 0.8364 - val_loss: 0.2438 - val_iou_metric: 0.7314 - lr: 1.0000e-04
# Epoch 49/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0317 - iou_metric: 0.8343
# Epoch 00049: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0317 - iou_metric: 0.8343 - val_loss: 0.2545 - val_iou_metric: 0.7333 - lr: 1.0000e-04
# Epoch 50/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0331 - iou_metric: 0.8324
# Epoch 00050: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0331 - iou_metric: 0.8324 - val_loss: 0.2404 - val_iou_metric: 0.7287 - lr: 1.0000e-04
# Epoch 51/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0314 - iou_metric: 0.8307
# Epoch 00051: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0314 - iou_metric: 0.8307 - val_loss: 0.2464 - val_iou_metric: 0.7234 - lr: 1.0000e-04
# Epoch 52/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0310 - iou_metric: 0.8358
# Epoch 00052: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0310 - iou_metric: 0.8358 - val_loss: 0.2471 - val_iou_metric: 0.7205 - lr: 1.0000e-04
# Epoch 53/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0317 - iou_metric: 0.8321
# Epoch 00053: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0317 - iou_metric: 0.8321 - val_loss: 0.2584 - val_iou_metric: 0.7258 - lr: 1.0000e-04
# Epoch 54/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0305 - iou_metric: 0.8431
# Epoch 00054: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0305 - iou_metric: 0.8431 - val_loss: 0.2539 - val_iou_metric: 0.7281 - lr: 1.0000e-04
# Epoch 55/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0303 - iou_metric: 0.8377
# Epoch 00055: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0303 - iou_metric: 0.8377 - val_loss: 0.2527 - val_iou_metric: 0.7185 - lr: 1.0000e-04
# Epoch 56/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0299 - iou_metric: 0.8361
# Epoch 00056: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0299 - iou_metric: 0.8361 - val_loss: 0.2599 - val_iou_metric: 0.7194 - lr: 1.0000e-04
# Epoch 57/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0300 - iou_metric: 0.8378
# Epoch 00057: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0300 - iou_metric: 0.8378 - val_loss: 0.2654 - val_iou_metric: 0.7254 - lr: 1.0000e-04
# Epoch 58/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0295 - iou_metric: 0.8388
# Epoch 00058: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 29s 159ms/step - loss: 0.0295 - iou_metric: 0.8388 - val_loss: 0.2669 - val_iou_metric: 0.7356 - lr: 1.0000e-04
# Epoch 59/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0296 - iou_metric: 0.8396
# Epoch 00059: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0296 - iou_metric: 0.8396 - val_loss: 0.2657 - val_iou_metric: 0.7264 - lr: 1.0000e-04
# Epoch 60/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0300 - iou_metric: 0.8394
# Epoch 00060: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0300 - iou_metric: 0.8394 - val_loss: 0.2693 - val_iou_metric: 0.7205 - lr: 1.0000e-04
# Epoch 61/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0293 - iou_metric: 0.8426
# Epoch 00061: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0293 - iou_metric: 0.8426 - val_loss: 0.2619 - val_iou_metric: 0.7308 - lr: 1.0000e-04
# Epoch 62/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0289 - iou_metric: 0.8442
# Epoch 00062: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0289 - iou_metric: 0.8442 - val_loss: 0.2624 - val_iou_metric: 0.7281 - lr: 1.0000e-04
# Epoch 63/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0281 - iou_metric: 0.8457
# Epoch 00063: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0281 - iou_metric: 0.8457 - val_loss: 0.2629 - val_iou_metric: 0.7337 - lr: 1.0000e-04
# Epoch 64/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0278 - iou_metric: 0.8443
# Epoch 00064: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0278 - iou_metric: 0.8443 - val_loss: 0.2729 - val_iou_metric: 0.7299 - lr: 1.0000e-04
# Epoch 65/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0274 - iou_metric: 0.8431
# Epoch 00065: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0274 - iou_metric: 0.8431 - val_loss: 0.2656 - val_iou_metric: 0.7198 - lr: 1.0000e-04
# Epoch 66/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0283 - iou_metric: 0.8447
# Epoch 00066: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0283 - iou_metric: 0.8447 - val_loss: 0.2644 - val_iou_metric: 0.7319 - lr: 1.0000e-04
# Epoch 67/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0275 - iou_metric: 0.8490
# Epoch 00067: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 157ms/step - loss: 0.0275 - iou_metric: 0.8490 - val_loss: 0.2628 - val_iou_metric: 0.7368 - lr: 1.0000e-04
# Epoch 68/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0273 - iou_metric: 0.8449
# Epoch 00068: val_iou_metric did not improve from 0.73832
# 180/180 [==============================] - 28s 158ms/step - loss: 0.0273 - iou_metric: 0.8449 - val_loss: 0.2716 - val_iou_metric: 0.7235 - lr: 1.0000e-04
# Epoch 00068: early stopping
# 1e-04

# %%
#model.save(r'./drive/My Drive/ImageProcessing/unet_input128_5_50ep_final.h5')

# %%
history[0].history.keys()
# Out:
# dict_keys(['loss', 'iou_metric', 'val_loss', 'val_iou_metric', 'lr'])

# %% [markdown]
# **101 GD Full**

# %%
f, (ax2, ax3) = plt.subplots(1, 2, figsize=(16, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history[0].epoch

ax2.plot(epoch_list, history[0].history['iou_metric'], label='Train IoU')
ax2.plot(epoch_list, history[0].history['val_iou_metric'], label='Validation IoU')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('IoU Value');ax2.set_xlabel('Epoch');ax2.set_title('IoU')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, history[0].history['loss'], label='Train Loss')
ax3.plot(epoch_list, history[0].history['val_loss'], label='Validation Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Loss Value');ax3.set_xlabel('Epoch');ax3.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
model.load_weights('./drive/My Drive/ImageProcessing/unet_input101_5_GD.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 25/25 [==============================] - 1s 58ms/step - loss: 0.2220 - iou_metric: 0.7440

# %%
#model.load_weights('./drive/My Drive/ImageProcessing/unet_input128_5_50ep.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 25/25 [==============================] - 2s 60ms/step - loss: 0.2882 - iou_metric: 0.7289

# %% [markdown]
# **50ep Normal**

# %%
f, (ax2, ax3) = plt.subplots(1, 2, figsize=(16, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history[0].epoch

ax2.plot(epoch_list, history[0].history['iou_metric'], label='Train IoU')
ax2.plot(epoch_list, history[0].history['val_iou_metric'], label='Validation IoU')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('IoU Value');ax2.set_xlabel('Epoch');ax2.set_title('IoU')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, history[0].history['loss'], label='Train Loss')
ax3.plot(epoch_list, history[0].history['val_loss'], label='Validation Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Loss Value');ax3.set_xlabel('Epoch');ax3.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
model.load_weights('/content/drive/MyDrive/ImageProcessing/New model/Unet_128_5_50ep/unet_input128_5_50ep_final.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 13/13 [==============================] - 1s 94ms/step - loss: 0.2170 - iou_metric: 0.6808

# %%
f, (ax2, ax3) = plt.subplots(1, 2, figsize=(16, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history[1].epoch

ax2.plot(epoch_list, history[1].history['iou_metric'], label='Train IoU')
ax2.plot(epoch_list, history[1].history['val_iou_metric'], label='Validation IoU')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('IoU Value');ax2.set_xlabel('Epoch');ax2.set_title('IoU')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, history[1].history['loss'], label='Train Loss')
ax3.plot(epoch_list, history[1].history['val_loss'], label='Validation Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Loss Value');ax3.set_xlabel('Epoch');ax3.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
model.load_weights('/content/drive/MyDrive/ImageProcessing/New model/Unet_128_5GD_50ep/unet_input128_5GD_50ep.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 13/13 [==============================] - 1s 94ms/step - loss: 0.1870 - iou_metric: 0.7000

# %%
f, (ax2, ax3) = plt.subplots(1, 2, figsize=(16, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history[2].epoch

ax2.plot(epoch_list, history[2].history['iou_metric'], label='Train IoU')
ax2.plot(epoch_list, history[2].history['val_iou_metric'], label='Validation IoU')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('IoU Value');ax2.set_xlabel('Epoch');ax2.set_title('IoU')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, history[2].history['loss'], label='Train Loss')
ax3.plot(epoch_list, history[2].history['val_loss'], label='Validation Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Loss Value');ax3.set_xlabel('Epoch');ax3.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
model.load_weights('/content/drive/MyDrive/ImageProcessing/unet_input128_5GD_100ep.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 13/13 [==============================] - 1s 93ms/step - loss: 0.1733 - iou_metric: 0.7007

# %% [markdown]
# **Try Train 100% data**

# %%
depths = pd.read_csv('./drive/My Drive/ImageProcessing/depths.csv')
data = pd.read_csv('./drive/My Drive/ImageProcessing/train.csv')
Data = pd.merge(data,depths,on='id',how='left')

# %%
from sklearn.preprocessing import LabelEncoder
X_train, X_test, y_train, y_test = train_test_split(Data, Data,  test_size=0.25, stratify=LabelEncoder().fit_transform(pd.qcut(Data.z,10)))

# %%
input_img=Input((128, 128, 1), name='img')
model=UNet(input_img)
model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=[iou_metric])
callbacks = [
ReduceLROnPlateau(patience=5, verbose=1, monitor='val_iou_metric', min_lr=0.0001, mode ='max', factor=0.5),
ModelCheckpoint('./drive/My Drive/ImageProcessing/unet_input128_5_submit.h5', monitor='val_iou_metric', mode = 'max', verbose=1, save_best_only=True),
EarlyStopping(monitor='val_iou_metric', mode='max', verbose=1, patience=40)
]

print("## GET DATA ##")
x_train, y_train, x_valid, y_valid = get_data(Data['id'].values, X_test['id'].values)
print('len(x_train):',len(x_train),'len(y_train):',len(y_train),'len(x_valid):',len(x_valid), 'len(y_valid):',len(y_valid))

# train the network
history_submit=model.fit(x_train, y_train, batch_size=32, epochs=100, callbacks=callbacks, validation_data=(x_valid,y_valid))
model.save(r'./drive/My Drive/ImageProcessing/unet_input128_5_submit_final.h5')
np.save('./drive/My Drive/ImageProcessing/my_history_unet_input128_5_submit.npy',history_submit.history)
print(K.eval(model.optimizer.lr))

# %%
f, (ax2, ax3) = plt.subplots(1, 2, figsize=(16, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history_submit.epoch

ax2.plot(epoch_list, history_submit.history['iou_metric'], label='Train IoU')
ax2.plot(epoch_list, history_submit.history['val_iou_metric'], label='Validation IoU')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('IoU Value');ax2.set_xlabel('Epoch');ax2.set_title('IoU')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, history_submit.history['loss'], label='Train Loss')
ax3.plot(epoch_list, history_submit.history['val_loss'], label='Validation Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Loss Value');ax3.set_xlabel('Epoch');ax3.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
model.load_weights('./drive/My Drive/ImageProcessing/unet_input128_5_submit.h5')
score = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 32/32 [==============================] - 3s 96ms/step - loss: 0.1730 - iou_metric: 0.7208

# %% [markdown]
# **Done**

# %%
def get_data_test(filetest):

  path='./drive/My Drive/ImageProcessing/dataset/train'
  
  
  x_test=[]
  y_test=[]


  #print(os.walk(path)
  for files in filetest:
    img,_,_ = load_image(path+'/images/'+files+'.png')
    mask,_,_ = load_image(path+'/masks/'+files+'.png')
    img=img/255.0
    mask=mask/255.0
    x_test.append(img)
    y_test.append(mask)
  return np.asarray(x_test), np.asarray(y_test)

# %%
#X_test=pd.read_csv('./drive/My Drive/ImageProcessing/test_400.csv') 

x_test, y_test = get_data_test(X_test['id'].values)

# %%
#model.load_weights('./drive/My Drive/ImageProcessing/unet_input128_5_50ep.h5')
score = model.evaluate(x_test, y_test, verbose=1)
